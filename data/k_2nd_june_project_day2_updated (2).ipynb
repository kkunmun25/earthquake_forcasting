# %% [markdown]
# # **Data/**

# %%
# !pip install obspy
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
# Out:
# Requirement already satisfied: obspy in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from obspy) (2.0.2)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.12/dist-packages (from obspy) (1.16.3)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from obspy) (3.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from obspy) (6.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from obspy) (75.2.0)
# Requirement already satisfied: sqlalchemy>=1.4 in /usr/local/lib/python3.12/dist-packages (from obspy) (2.0.50)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from obspy) (4.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from obspy) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy) (2.9.0.post0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4->obspy) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4->obspy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->obspy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->obspy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->obspy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->obspy) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->obspy) (1.17.0)

# %%
client = Client("USGS")
catalog=client.get_events(starttime=UTCDateTime("2016-05-30"),endtime=UTCDateTime("2026-05-30"),minmagnitude=4,minlatitude=6,maxlatitude=15,minlongitude=90,maxlongitude=98)
print(catalog)
print("number of events:",len(catalog))
# Out:
# 924 Event(s) in Catalog:
# 2026-05-17T09:38:20.742000Z | +11.062,  +95.127 | 4.6  mb | manual
# 2026-05-16T21:16:16.654000Z | +13.017,  +93.702 | 4.7  mb | manual
# ...
# 2016-07-13T17:56:32.830000Z | +12.082,  +95.170 | 4.5  mb | manual
# 2016-06-13T00:16:58.710000Z |  +6.384,  +94.355 | 4.2  mb | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'
# number of events: 924

# %%
import pandas as pd
rows=[]
for event in catalog:
 origin=event.origins[0]
 mag=event.magnitudes[0]

 rows.append({"time":origin.time.datetime,"latitude":origin.latitude,"longitude":origin.longitude,"depth_km":origin.depth/1000,"magnitude":mag.mag})
df=pd.DataFrame(rows)
print(df.head(10))
# Out:
#                      time  latitude  longitude  depth_km  magnitude
# 0 2026-05-17 09:38:20.742   11.0619    95.1269    10.000        4.6
# 1 2026-05-16 21:16:16.654   13.0167    93.7021    96.882        4.7
# 2 2026-05-12 05:18:57.354    6.9852    92.3567    10.000        4.9
# 3 2026-05-08 03:53:33.205   10.1728    91.4911    10.000        4.6
# 4 2026-05-03 10:33:34.042    8.1018    91.9353    10.000        4.2
# 5 2026-05-01 03:12:50.564    8.0760    91.8795    10.000        4.8
# 6 2026-04-10 03:36:01.376    9.0424    94.0030    10.000        4.3
# 7 2026-04-08 22:13:51.268   10.4649    93.7220    10.000        4.6
# 8 2026-04-05 00:05:48.007    6.2934    92.4536    10.000        4.0
# 9 2026-04-01 20:14:23.446    6.1734    94.0331    41.062        4.4

# %%
df.to_csv("USGS andaman_nicobar_M4_catalog.csv", index=False)

print("CSV saved successfully")
# Out:
# CSV saved successfully

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

df = pd.read_csv(Path("USGS andaman_nicobar_M4_catalog.csv"))

df.head()
# Out:
#                       time  latitude  longitude  depth_km  magnitude
# 0  2026-05-17 09:38:20.742   11.0619    95.1269    10.000        4.6
# 1  2026-05-16 21:16:16.654   13.0167    93.7021    96.882        4.7
# 2  2026-05-12 05:18:57.354    6.9852    92.3567    10.000        4.9
# 3  2026-05-08 03:53:33.205   10.1728    91.4911    10.000        4.6
# 4  2026-05-03 10:33:34.042    8.1018    91.9353    10.000        4.2

# %% [markdown]
# # **3.notebooks/03_baseline_forecast**

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2026.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1

# %%
#creating monthly counts
df['time'] = pd.to_datetime(df['time'])
monthly_counts = df.set_index('time').resample('MS').size()
monthly_counts.head()
# Out:
# time
# 2016-06-01     1
# 2016-07-01     3
# 2016-08-01     7
# 2016-09-01    11
# 2016-10-01     2
# Freq: MS, dtype: int64

# %%
#plotting monthly counts
plt.figure(figsize=(12,4))

plt.plot(monthly_counts.index,
         monthly_counts.values)

plt.title("Monthly Earthquake Counts")
plt.ylabel("Count")
plt.xlabel("Year")

plt.grid(True)
plt.show()

# %% [markdown]
# ## **(a)Train on 80%,forecast remaining 20%**

# %%
#Train-Test split(80%-20%)
split_idx = int(len(monthly_counts)*0.8)

train = monthly_counts.iloc[:split_idx]
test  = monthly_counts.iloc[split_idx:]

print("Training observations :", len(train))
print("Testing observations  :", len(test))
# Out:
# Training observations : 96
# Testing observations  : 24

# %%
plt.figure(figsize=(12,4))

plt.plot(train,label="Train")
plt.plot(test,label="Test")

plt.legend()
plt.title("80-20 Train-Test Split")
plt.show()

# %%
#check stationary (ADF Test)
from statsmodels.tsa.stattools import adfuller

result = adfuller(train)

print("ADF Statistic :", result[0])
print("p-value       :", result[1])
# Out:
# ADF Statistic : -8.967327149842728
# p-value       : 7.924155768248149e-15

# %%
#ACF and PACF
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(train,lags=24)
plt.show()

plot_pacf(train,lags=24)
plt.show()

# %% [markdown]
# ## **(b)fit ARIMA on monthly counts**

# %%
#fit ARIMA
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train, order=(1,0,1))

fit = model.fit()

print(fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   96
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -372.453
# Date:                Mon, 15 Jun 2026   AIC                            752.907
# Time:                        09:48:54   BIC                            763.164
# Sample:                    06-01-2016   HQIC                           757.053
#                          - 05-01-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.7612      3.357      2.312      0.021       1.181      14.342
# ar.L1         -0.8743      0.138     -6.331      0.000      -1.145      -0.604
# ma.L1          0.9998      7.224      0.138      0.890     -13.159      15.159
# sigma2       134.3986    969.754      0.139      0.890   -1766.284    2035.081
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              3057.56
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.41   Skew:                             4.79
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## **(c)Log-Likelihood score**

# %%
#Log-Likelihood
print("Log-Likelihood =", fit.llf)
# Out:
# Log-Likelihood = -372.453309642538

# %% [markdown]
# ## **(d)Forecast Remaining**

# %%
#forecast test period
forecast = fit.forecast(steps=len(test))
forecast.index = test.index
forecast.head()
# Out:
# time
# 2024-06-01    8.546300
# 2024-07-01    7.074697
# 2024-08-01    8.361369
# 2024-09-01    7.236388
# 2024-10-01    8.219997
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## **(e)Report RMSE and MAE**

# %%
#RMSE and MAE
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

mae = mean_absolute_error(test,forecast)
rmse = np.sqrt(mean_squared_error(test,forecast))

print("MAE  =", mae)
print("RMSE =", rmse)
# Out:
# MAE  = 6.460830008616387
# RMSE = 10.449583505236594

# %% [markdown]
# ## **(F)Compare to a naive "last-year-mean"baseline**

# %%
#building naive last-year-mean baseline
baseline_mean = train.iloc[-12:].mean()

baseline_forecast = pd.Series(baseline_mean,index=test.index)
baseline_forecast.head()
# Out:
# time
# 2024-06-01    7.75
# 2024-07-01    7.75
# 2024-08-01    7.75
# 2024-09-01    7.75
# 2024-10-01    7.75
# Freq: MS, dtype: float64

# %%
baseline_mae = mean_absolute_error(test,baseline_forecast)
baseline_rmse = np.sqrt(mean_squared_error(test,baseline_forecast))

print("Baseline MAE  =", baseline_mae)
print("Baseline RMSE =", baseline_rmse)
# Out:
# Baseline MAE  = 6.375
# Baseline RMSE = 10.436314802968846

# %%
comparison = pd.DataFrame({"Model":["ARIMA","Last-Year-Mean"],"MAE":[mae,baseline_mae],
  "RMSE":[rmse, baseline_rmse]})

comparison
# Out:
#             Model      MAE       RMSE
# 0           ARIMA  6.46083  10.449584
# 1  Last-Year-Mean  6.37500  10.436315

# %%
plt.figure(figsize=(12,4))

plt.plot(test,label="Observed")
plt.plot(forecast,label="ARIMA")
plt.plot(baseline_forecast,label="Baseline")
plt.legend()
plt.title("Forecast Comparison")
plt.show()

# %% [markdown]
# # **5.src/eq_pipeline(with docstrings and type-hints)**

# %%
import os
os.makedirs("src/eq_pipeline", exist_ok=True)

# %%
# %%writefile src/eq_pipeline/__init__.py
from .ingest import load_catalog
from .stats import calculate_b_value
from .forecast import forecast_rate
# Out:
# Writing src/eq_pipeline/__init__.py

# %%
# %%writefile src/eq_pipeline/ingest.py

import pandas as pd

def load_catalog(file_path: str) -> pd.DataFrame:
    """
    Load earthquake catalog from CSV file.

    Parameters
    ----------
    file_path : str
        Path to earthquake catalog CSV.

    Returns
    -------
    pd.DataFrame
        Earthquake catalog.
    """
    return pd.read_csv(file_path)
# Out:
# Overwriting src/eq_pipeline/ingest.py

# %%
# %%writefile src/eq_pipeline/stats.py

import numpy as np

def calculate_b_value(magnitudes,mc,dM=0.1):
    """
    Calculate Gutenberg–Richter b-value.
    """

    mean_mag = np.mean(magnitudes)

    b = 1 / (np.log(10) *(mean_mag - mc + dM/2))
    return b


def bootstrap_b_value(magnitudes,mc,dM=0.1,n_boot=1000):
    """
    Bootstrap confidence interval for b-value.
    """

    boot_b = []

    for _ in range(n_boot):

        sample = np.random.choice(magnitudes,size=len(magnitudes),replace=True)
        mean_sample = np.mean(sample)

        b_sample = 1 / (np.log(10) *(mean_sample - mc + dM/2))
        boot_b.append(b_sample)

    ci_low = np.percentile(boot_b, 2.5)
    ci_high = np.percentile(boot_b, 97.5)

    return ci_low, ci_high
# Out:
# Overwriting src/eq_pipeline/stats.py

# %%
# %%writefile src/eq_pipeline/forecast.py

from statsmodels.tsa.arima.model import ARIMA

def forecast_rate(train, steps, order=(1,1,1)):
  """
    Estimate earthquake occurrence rate.

    Parameters
    ----------
    data : pd.DataFrame
        Earthquake catalog.

    Returns
    -------
    float
        Estimated daily event rate.
    """

    model = ARIMA(train, order=order)

    fitted_model = model.fit()

    forecast = fitted_model.forecast(steps=steps)

    return fitted_model, forecast
# Out:
# Overwriting src/eq_pipeline/forecast.py

# %%
# %%writefile src/eq_pipeline/__init__.py
"""
Earthquake forecasting pipeline package.

This package contains modules for data ingestion,
statistical analysis, and forecasting.
"""

from .ingest import load_catalog
from .stats import calculate_b_value
from .forecast import forecast_rate
# Out:
# Overwriting src/eq_pipeline/__init__.py

# %%
import sys
sys.path.append("src")

# %%
data = pd.read_csv(Path("USGS andaman_nicobar_M4_catalog.csv"))

# %% [markdown]
# # **6.README.md**

# %%
# %%writefile README.md
# # Earthquake Forecasting Project
#
# This project analyzes earthquake catalog data and computes b-value and Mc.
#
# ## How to Reproduce
#
# 1. Create environment:
#
# conda env create -f environment.yml
#
# 2. Activate environment:
#
# conda activate earthquake_env
#
# 3. Start Jupyter:
#
# jupyter lab
#
# 4. Run the notebook.
#
# ## Figures
#
# - Figure 1: Magnitude Distribution
# - Figure 2: ACF Plot
# - Figure 3: PACF Plot
# Out:
# Writing README.md

# %%
from pathlib import Path

Path("figures").mkdir(exist_ok=True)

# %%
import matplotlib.pyplot as plt
plt.savefig("figures/magnitude_distribution.png")
plt.savefig("figures/acf.png")
plt.savefig("figures/Pacf.png")

# %%
#ACF plot
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,4))
plot_acf(train, ax=ax)

plt.tight_layout()
fig.savefig("figures/acf.png")

plt.show()

# %%
#PACF Plot
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,4))
plot_pacf(train, ax=ax)

plt.tight_layout()
fig.savefig("figures/pacf.png")

plt.show()

# %%
#magnitude-distribution
plt.figure(figsize=(12,4))

plt.plot(monthly_counts.index,
         monthly_counts.values)

plt.title("Monthly Earthquake Counts")
plt.ylabel("Count")
plt.xlabel("Year")

plt.grid(True)
fig.savefig("figures/magnitude_distribution.png")
plt.show()

# %% [markdown]
# # **7.enviroment.yml**

# %%
# %%writefile environment.yml
# name: earthquake_env
#
# channels:
#   - conda-forge
#
# dependencies:
#   - python=3.11
#   - numpy
#   - pandas
#   - scipy
#   - matplotlib
#   - scikit-learn
#   - statsmodels
#   - pmdarima
#   - obspy
#   - cartopy
# Out:
# Writing environment.yml
