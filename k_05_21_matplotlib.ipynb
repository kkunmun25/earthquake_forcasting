# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
frequency=[10000,3000,900,300,90,30]
magnitude=[0,1,2,3,4,5]
plt.loglog(magnitude, frequency, '+-',color='green')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Gutenberg-Richter Law')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 100, 100)

y1 = x
y2 = x**2
y3 = x**3

plt.loglog(x, y1, label="x")
plt.loglog(x, y2, label="x^2")
plt.loglog(x, y3, label="x^3")

plt.legend()
plt.grid(True)

plt.title("Multiple Power Laws")
plt.show()

# %%
import pandas as pd
from pathlib import Path

# Define CSV file path in Downloads
csv_file = Path.home() / "Downloads" / "batter.csv"

# Load the CSV file
batter = pd.read_csv(csv_file)
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(batter['avg'],batter['strike_rate'],color='green',marker='+')
ax[0,1].scatter(batter['avg'],batter['runs'],color='red',marker='+')
ax[1,0].hist(batter['avg'])
ax[1,1].hist(batter['runs'],color='red')
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
from pathlib import Path
csv_file = Path.home() / "Downloads" / "sharma-kohli.csv"
batsman = pd.read_csv(csv_file)

plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['V Kohli'], color='green', linestyle='solid', linewidth=2, marker='D', markersize=5, label='virat')
plt.plot(batsman['index'], batsman['RG Sharma'], color='black', linestyle='dashed', linewidth=3, marker='o', markersize=8, label='Rohit')
plt.legend()
plt.title('Rohit Sharma vs Virat Kohli carrer comparision')
plt.xlabel('Matches')
plt.ylabel('Runs')
plt.grid()
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid',linewidth=2,marker='D',markersize=5,label='virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',linewidth=3,marker='o',markersize=8,label='Rohit')
plt.legend()
plt.title('Rohit Sharma vs Virat Kohli carrer comparision')
plt.xlabel('Matches')
plt.ylabel('Runs')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 import pandas as pd
# ----> 2 batsman=pd.read_csv('sharma-kohli.csv')
#       3 plt.plot(batsman['index'],batsman['V Kohli'])
#       4 plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid',linewidth=2,marker='D',markersize=5,label='virat')
#
# ...
